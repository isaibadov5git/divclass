# %%
meyveler = ['alma','armud','qarpiz',1,2,3,None,True]
meyveler
meyveler[::-1]
# Out:
# [True, None, 3, 2, 1, 'qarpiz', 'armud', 'alma']

# %%
print(list('ciyelek'))
meyveler[3:7] = 'ciyelek'
meyveler
'alma' not in meyveler
# Out:
# ['c', 'i', 'y', 'e', 'l', 'e', 'k']
# True

# %%
meyveler = ['ciyelek','alma','armud','qarpiz']
# Output methods
meyveler.sort() # method is the specific function
meyveler.sort(reverse=True) # Output None, just changes
meyveler.append('ufaz')
#meyveler2 = meyveler.copy()
del meyveler[0]
meyveler
# Out:
# ['ciyelek', 'armud', 'alma', 'ufaz']

# %%
age = 20

if age < 3:
    print('baby')
elif age < 15:
    print('teenager')
elif age<=19:
    print('supheli')
elif age < 25:
    print('adult')
else:
    print("You are an adult")
# Out:
# adult

# %%
colors = ['red','green','blue','yellow','purple']
print(colors[2])
print(colors[-1])
primary_colors = colors[0:3]
primary_colors
# Out:
# blue
# purple
# ['red', 'green', 'blue']

# %%
colors = ['red','green','blue','yellow','purple']
colors[3] = 'magenta'
colors.append('cyan')
print(colors)
colors.insert(1,'orange')
print(colors)
colors.remove('blue')
print(colors)
# Out:
# ['red', 'green', 'blue', 'magenta', 'purple', 'cyan']
# ['red', 'orange', 'green', 'blue', 'magenta', 'purple', 'cyan']
# ['red', 'orange', 'green', 'magenta', 'purple', 'cyan']

# %%
tic_tac_toe = [['X','O','X'],
               ['O','X','O'],
               ['X','O',' ']]

print(tic_tac_toe[1][1])
tic_tac_toe[2][2] = 'O'
print(tic_tac_toe)
# Out:
# X

# %%
weekdays = ("Monday","Tuesday","Wednesday","Thirsday","Friday")
#weekdays[0] = "Funday"
print(weekdays)
print(weekdays[3])
# Out:
# ('Monday', 'Tuesday', 'Wednesday', 'Thirsday', 'Friday')
# Thirsday

# %%
grade = int(input("Enter your grade: "))

if grade < 60:
    print("F")
elif grade < 70:
    print("D")
elif grade < 80:
    print("C")
elif grade < 90:
    print("B")
else:
    print("A")
# Out:
# F

# %%
print((10 > 5) and (5 < 3))
print((10 > 5) or (5 < 3))
print(not (5 == 5))
print(1 < 3 < 5)
print(1 < 3 and 3 > 5)
# Out:
# False
# True
# False
# True
# False

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[75], line 2
#       1 string = 'isa'
# ----> 2 string[0] = 'o'
#       3 print(string)
#
# TypeError: 'str' object does not support item assignment
