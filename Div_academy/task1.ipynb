# %%
# ----------------------------
# BEGINNER
# ----------------------------

# Task 1: Lambda funksiyası ilə ədədin kubunu tapmaq
# Lambda funksiyası sadə bir funksiyadır ki, bir sətirdə yazılır.
# Biz cube adlı dəyişənə bu funksiyanı veririk.
# Funksiya daxil olan ədədin kubunu qaytarır.


# Task 2: List comprehension ilə tək ədədlər
# 1-dən 15-ə qədər olan ədədlərdən yalnız tək ədədləri siyahıya əlavə edirik.
# List comprehension çox qısa və oxunaqlı yoludur.


# Task 3: Basic try...except – Float tipində ədəd alma
# İstifadəçidən float ədəd alırıq.
# Əgər istifadəçi ədəd əvəzinə hərf və ya başqa şey daxil etsə ValueError yaranacaq.
# try...except blokunda bu səhvi tuturuq.


# ----------------------------
# INTERMEDIATE
# ----------------------------

# Task 1: Lambda + map – Sözlərin uzunluğunu tapmaq
# map funksiyası siyahıdakı hər elementi təyin olunmuş funksiyadan keçirir.
# Lambda ilə hər sözü tuple şəklində (söz, uzunluğu) veririk.


# Task 2: Filter – 4-ə bölünən ədədləri seçmək
# filter funksiyası şərtə uyğun olan elementləri seçir.


# Task 3: Dictionary comprehension – Meyvə sözlükləri
# Siyahıdakı meyvələrin ilk hərfi açar, meyvənin özü isə dəyər olacaq.


# ----------------------------
# ADVANCED
# ----------------------------


# Task 1: Raise Exception, yash yoxlayici + Email yoxlayici

# %%
cube = lambda x: x**3
cube(2)
# Out:
# 8

# %%
odd_numbers = [i for i in range(1,15) if i%2!=0]
odd_numbers
# Out:
# [1, 3, 5, 7, 9, 11, 13]

# %%
try:
    number = float(input("Enter a float number: "))
except ValueError as e:
    print("Valueerror happened")

# number = float(input("Enter a float number: "))

# %%
sozler = ["ufaz","banm","ada","adpiu"]

uzunluqlar = map(lambda x: (x,len(x)),sozler)
list(uzunluqlar)

numbers = [1,2,4,8,6,12,16,7,9]

list(filter(lambda num: num%4==0,numbers))
# Out:
# [4, 8, 12, 16]

# %%
meyveler = ["alma","mandalin","ciyelek","qarpiz"]

{meyve[0]:meyve for meyve in meyveler}
# Out:
# {'a': 'alma', 'm': 'mandalin', 'c': 'ciyelek', 'q': 'qarpiz'}

# %%
def yashyoxlayici(yash):
    if yash <=0:
        raise Exception("Yash menfi ola bilmez")
    print(f"{yash}")

def emailyoxlayici(email):
    if "@" not in email:
        raise Exception("Email etibarli deyil")
    print(f"{email}")

emailyoxlayici("isaibadov5gmail.com")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[20], line 11
#       8         raise Exception("Email etibarli deyil")
#       9     print(f"{email}")
# ---> 11 emailyoxlayici("isaibadov5gmail.com")
#
# Cell In[20], line 8, in emailyoxlayici(email)
#       6 def emailyoxlayici(email):
#       7     if "@" not in email:
# ----> 8         raise Exception("Email etibarli deyil")
#       9     print(f"{email}")
#
# Exception: Email etibarli deyil

# %%
class Employee():
    def __init__(self,name,salary):
        self.name = name
        self.salary = salary

class Manager(Employee):
    def __init__(self, name, salary, team_size):
        self.team_size = team_size
        super().__init__(name,salary)

    def __str__(self):
        return self.name
    def details(self):
        return self.team_size
    


manager = Manager(50)
