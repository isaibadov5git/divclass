# %% [markdown]
# #### Exercise 1: Arithmetic operators

# %%
print(10+5*3)
print((10+5)*3)
print(20/4)
print(20//4)
print(21//4)
print(21%4)
print(2**5)
# Out:
# 25
# 45
# 5.0
# 5
# 5
# 1
# 32

# %% [markdown]
# #### Exercise 2: Operator precedence

# %%
5+3*2-8/4**2
# Out:
# 10.5

# %% [markdown]
# #### Exercise 3: Comparison Operators

# %%
print(50>100)
print(33 == 33.0)
print("hello"!="world")
len("python")>=5
# Out:
# False
# True
# True
# True

# %% [markdown]
# #### Exercise 1: Variables

# %%
city = "New York"
print(city)
city = "London"
print(city)
# Out:
# New York
# London

# %% [markdown]
# #### Exercise 2: Assignment variables

# %%
score = 100
score = score - 25
score = score * 2
score
# Out:
# 150

# %% [markdown]
# #### Exercise 3: Variable Naming

# %%
1st_place = 1 # firs term should not be number
first-place = 1 # "-" cannot be used when naming
_first_place = 1 # Valid
for = 1 # Keywords cannot be used as a variable name
FirstPlace = 1 # Valid

# %% [markdown]
# #### Exercise 4: Data Types

# %%
print(type(99))
print(type("99"))
print(type(99.0))
print(type(False))
print(type(None))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'bool'>
# <class 'NoneType'>

# %% [markdown]
# #### Exercise 5: Type Conversion

# %%
price_str = "25.99"
price_float = float(price_str)
quantity = 3
strquantity = str(quantity)
print(strquantity + "items")
# Out:
# 3items

# %% [markdown]
# #### Exercise 1: Concatenation and Replication

# %%
first_name = "Isa"
last_name = "Ibadov"
full_name = first_name + " " + last_name
separator = '-'*30
print(full_name)
print(separator)
# Out:
# Isa Ibadov
# ------------------------------

# %% [markdown]
# #### Exercise 2: Escape Characters

# %%
text = 'The file is located at: \nC:\\Users\\new_folder\\tabbed_file.txt \nHe said, "It\'s a beautiful day."'
print(text)
# Out:
# The file is located at:
# C:\Users\new_folder\tabbed_file.txt
# He said, "It's a beautiful day."

# %% [markdown]
# #### Exercise 3: Indexing and Slicing

# %%
s = "Programming is fun!"
print(s[4])
print(s[-1])
print(s[11:13])
print(s[3:7])
print(s[::-1])
# Out:
# r
# !
#  i
# gram
# !nuf si gnimmargorP

# %% [markdown]
# #### Exercise 4: String Methods

# %%
tweet = "  Wow, what a great game! #sports #python  "
print(tweet.lower())
print(tweet.strip())
print(tweet.replace("#python","#DataScience"))
print(tweet.split())
# Out:
#   wow, what a great game! #sports #python
# Wow, what a great game! #sports #python
#   Wow, what a great game! #sports #DataScience
# ['Wow,', 'what', 'a', 'great', 'game!', '#sports', '#python']

# %% [markdown]
# #### Exercise 1: User Greeting

# %%
Name = input("Enter your name: ")
print(f"Hello, {Name}!")
# Out:
# Hello, Isa!

# %% [markdown]
# #### Exercise 2: Age Calculator

# %%
current_year = input("Enter the current year: ")
birth_year = input("Enter your birth year: ")
age = int(current_year) - int(birth_year)
print(f"Your age is {age}")
# Out:
# Your age is 19

# %% [markdown]
# #### Exercise 3: Formattet Output

# %%
item = "Laptop"
price = 1200.50
quantity = 2
total_cost = price * quantity
print(f"Item: {item}, Quantity: {quantity}, Total Cost: ${total_cost:,.2f}")
# Out:
# Item: Laptop, Quantity: 2, Total Cost: $2,401.00
